# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from datetime import datetime

# %%
path = 'df2_filter1_nov.csv'
df = pd.read_csv(path)
df = df.drop({'Unnamed: 0.1'},axis=1)
df
# Out:
#                                         maid  latitude   longitude  \
# 0       375bc2e5-1e09-4620-a780-c75d5a6aeb69 -7.775690  110.377663
# 1       375bc2e5-1e09-4620-a780-c75d5a6aeb69 -7.775680  110.377647
# 2       ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776310  110.377251
# 3       ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776340  110.377258
# 4       ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776320  110.377258
# ...                                      ...       ...         ...
# 527281  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
# 527282  673296f6-23f2-4195-8364-750194a85502 -7.783890  110.374588
# 527283  673296f6-23f2-4195-8364-750194a85502 -7.783890  110.374588
# 527284  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
# 527285  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
#
#                datetime_wib                              geometry  \
# 0       2021-11-01 00:11:19    POINT (110.3776626586914 -7.77569)
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527286 entries, 0 to 527285
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   maid            527286 non-null  object
#  1   latitude        527286 non-null  float64
#  2   longitude       527286 non-null  float64
#  3   datetime_wib    527286 non-null  object
#  4   geometry        527286 non-null  object
#  5   Kelurahan/Desa  527286 non-null  object
#  6   Kecamatan       527286 non-null  object
#  7   Kabupaten       527286 non-null  object
#  8   tanggal         527286 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 36.2+ MB

# %% [markdown]
# ## Remove N/A and duplicate value

# %%
df.dropna(inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 527286 entries, 0 to 527285
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   maid            527286 non-null  object
#  1   latitude        527286 non-null  float64
#  2   longitude       527286 non-null  float64
#  3   datetime_wib    527286 non-null  object
#  4   geometry        527286 non-null  object
#  5   Kelurahan/Desa  527286 non-null  object
#  6   Kecamatan       527286 non-null  object
#  7   Kabupaten       527286 non-null  object
#  8   tanggal         527286 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 36.2+ MB

# %%
df[df.duplicated()]
# Out:
#                                         maid  latitude   longitude  \
# 5       ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776320  110.377258
# 11      375bc2e5-1e09-4620-a780-c75d5a6aeb69 -7.775863  110.377472
# 16      fc575bae-f23e-4764-a77b-f763ca4f0256 -7.774310  110.375999
# 21      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# 22      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# ...                                      ...       ...         ...
# 527281  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
# 527282  673296f6-23f2-4195-8364-750194a85502 -7.783890  110.374588
# 527283  673296f6-23f2-4195-8364-750194a85502 -7.783890  110.374588
# 527284  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
# 527285  673296f6-23f2-4195-8364-750194a85502 -7.783883  110.374596
#
#                datetime_wib                              geometry  \
# 5       2021-11-01 00:15:01   POINT (110.37725830078124 -7.77632)
# ...

# %%
date_string = "2021-11-25"
df[(['maid'] == '97a0f36f-5209-451c-80bd-69cceca4cab0') & (df['tanggal'] == datetime.strptime(date_string, "%Y-%m-%d").date)]
# Out:
# Empty DataFrame
# Columns: [maid, latitude, longitude, datetime_wib, geometry, Kelurahan/Desa, Kecamatan, Kabupaten, tanggal]
# Index: []

# %%
df[df['maid'] == '97a0f36f-5209-451c-80bd-69cceca4cab0']
# Out:
#                                         maid  latitude   longitude  \
# 19      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# 20      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# 21      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# 22      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# 23      97a0f36f-5209-451c-80bd-69cceca4cab0 -7.774979  110.373039
# ...                                      ...       ...         ...
# 503728  97a0f36f-5209-451c-80bd-69cceca4cab0 -7.775320  110.373428
# 503729  97a0f36f-5209-451c-80bd-69cceca4cab0 -7.775320  110.373444
# 503730  97a0f36f-5209-451c-80bd-69cceca4cab0 -7.775320  110.373428
# 503731  97a0f36f-5209-451c-80bd-69cceca4cab0 -7.775320  110.373413
# 503732  97a0f36f-5209-451c-80bd-69cceca4cab0 -7.775320  110.373444
#
#                datetime_wib                              geometry  \
# 19      2021-11-01 07:02:52  POINT (110.37303924560548 -7.774979)
# ...

# %%
df = df.drop_duplicates()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 520696 entries, 0 to 527285
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0.1    520696 non-null  int64
#  1   maid            520696 non-null  object
#  2   latitude        520696 non-null  float64
#  3   longitude       520696 non-null  float64
#  4   datetime_wib    520696 non-null  object
#  5   geometry        520696 non-null  object
#  6   Kelurahan/Desa  520696 non-null  object
#  7   Kecamatan       520696 non-null  object
#  8   Kabupaten       520696 non-null  object
#  9   tanggal         520696 non-null  object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 43.7+ MB

# %%
def bar_chart(data):
    filtered_data = data.copy()

    # Hapus duplikat 'maid' berdasarkan tanggal
    filtered_data_unique_maid = filtered_data.drop_duplicates(subset=['tanggal', 'maid'])

    # Hitung jumlah unik per hari
    jumlah_unik_per_hari = filtered_data_unique_maid.groupby('tanggal').size()

    # Plotting
    plt.figure(figsize=(10, 6))
    jumlah_unik_per_hari.plot(kind='bar', color='skyblue')
    plt.title('Jumlah Data Maid unik per Hari')
    plt.xlabel('Tanggal')
    plt.ylabel('Jumlah Data Unik')
    plt.xticks(rotation=75)
    plt.show()

# %%
bar_chart(df)

# %% [markdown]
# ## Set minimum threshold of user ID occurence to 10
#
# after that, we do the same data evaluation using uid occurence histogram

# %%
ids = df['maid'].value_counts()
ids
# Out:
# maid
# 97a0f36f-5209-451c-80bd-69cceca4cab0    36574
# a2b6a27a-35e9-4735-909b-6cfbafd288ac    24424
# d1411a0f-6063-44ff-a0cb-a19a9409ad8d    15712
# 85b47c1f-b130-4133-a296-e41987180782    14246
# d9f515f4-1a78-442b-81c4-55bf5f253b91    13018
#                                         ...
# a70cd5a7-f2f8-435e-aa3c-fe871aed7ede        1
# 205068fc-b107-40d8-8a69-eded2ec4ca97        1
# d72fd576-2eed-458d-8552-01c45d47cdbd        1
# 59f477d1-3e3b-4d34-844d-e30fd854e703        1
# 31ba9cf1-4155-474e-acd8-51da9a08e82b        1
# Name: count, Length: 3949, dtype: int64

# %%
# filtering to minimum 10 mobilities

valid_ids = ids[ids >= 10].index.tolist()
# filter dataframe to include only valid IDs
filtered_df = df[df['maid'].isin(valid_ids)]
filtered_df.shape
# Out:
# (514268, 10)

# %%
bar_chart(filtered_df)
# Out:
# /tmp/ipykernel_31952/1735645082.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['datetime_wib'] = pd.to_datetime(filtered_data['datetime_wib'])
# /tmp/ipykernel_31952/1735645082.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_data['tanggal'] = filtered_data['datetime_wib'].dt.date

# %%
filtered_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 514268 entries, 0 to 527285
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Unnamed: 0.1    514268 non-null  int64
#  1   maid            514268 non-null  object
#  2   latitude        514268 non-null  float64
#  3   longitude       514268 non-null  float64
#  4   datetime_wib    514268 non-null  datetime64[ns]
#  5   geometry        514268 non-null  object
#  6   Kelurahan/Desa  514268 non-null  object
#  7   Kecamatan       514268 non-null  object
#  8   Kabupaten       514268 non-null  object
#  9   tanggal         514268 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(6)
# memory usage: 43.2+ MB

# %% [markdown]
# ## Noise Outlier filter with Scikit-mobility

# %%
import skmob
from skmob import preprocessing

tdf = skmob.TrajDataFrame(df,latitude='latitude',longitude='longitude',user_id='maid',datetime='datetime_wib')
tdf
# Out:
#         Unnamed: 0.1                                   uid       lat  \
# 0            3625664  375bc2e5-1e09-4620-a780-c75d5a6aeb69 -7.775690
# 1            3625667  375bc2e5-1e09-4620-a780-c75d5a6aeb69 -7.775680
# 2            3625675  ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776310
# 3            3625676  ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776340
# 4            3625698  ce6ec216-64cc-444b-80fc-39cc3ea1b51c -7.776320
# ...              ...                                   ...       ...
# 527281      16556877  673296f6-23f2-4195-8364-750194a85502 -7.783883
# 527282      16556878  673296f6-23f2-4195-8364-750194a85502 -7.783890
# 527283      16556879  673296f6-23f2-4195-8364-750194a85502 -7.783890
# 527284      16556880  673296f6-23f2-4195-8364-750194a85502 -7.783883
# 527285      16556881  673296f6-23f2-4195-8364-750194a85502 -7.783883
#
#                lng            datetime                              geometry  \
# ...

# %%
tdf.info()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[110], line 1
# ----> 1 tdf.info()
#
# File ~/miniconda3/envs/arkham/lib/python3.10/site-packages/pandas/core/frame.py:3464, in DataFrame.info(self, verbose, buf, max_cols, memory_usage, show_counts)
#    3451 @doc(INFO_DOCSTRING, **frame_sub_kwargs)
#    3452 def info(
#    3453     self,
#    (...)
#    3458     show_counts: bool | None = None,
#    3459 ) -> None:
#    3460     info = DataFrameInfo(
#    3461         data=self,
#    3462         memory_usage=memory_usage,
#    3463     )
# -> 3464     info.render(
#    3465         buf=buf,
#    3466         max_cols=max_cols,
#    3467         verbose=verbose,
#    3468         show_counts=show_counts,
#    3469     )
#
# ...
