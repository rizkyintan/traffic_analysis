# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
from geopandas import GeoDataFrame
from shapely.geometry import Point
import skmob
from skmob.preprocessing import filtering
from skmob.preprocessing import detection
from skmob.preprocessing import compression
import folium
import os

# %%
path = './DataGPS_Malioboro/filter2_malioboro_des.csv'
df = pd.read_csv(path)
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38828 entries, 0 to 38827
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   maid            38828 non-null  object
#  1   latitude        38828 non-null  float64
#  2   longitude       38828 non-null  float64
#  3   datetime_wib    38828 non-null  object
#  4   geometry        38828 non-null  object
#  5   Kelurahan/Desa  38828 non-null  object
#  6   Kecamatan       38828 non-null  object
#  7   Kabupaten       38828 non-null  object
#  8   tanggal         38828 non-null  object
# dtypes: float64(2), object(7)
# memory usage: 2.7+ MB
#                                    maid  latitude   longitude  \
# 0  d60a2068-d7ea-48a7-a363-e3e7e0bd02cb -7.794847  110.365608
# 1  3ad1fad6-400a-4ae9-8610-c2d355dcd9f9 -7.794029  110.365944
# 2  d60a2068-d7ea-48a7-a363-e3e7e0bd02cb -7.794847  110.365608
# 3  3ad1fad6-400a-4ae9-8610-c2d355dcd9f9 -7.794029  110.365944
# 4  3ad1fad6-400a-4ae9-8610-c2d355dcd9f9 -7.794029  110.365944
#
#           datetime_wib                              geometry  \
# 0  2021-12-01 00:00:35  POINT (110.36560821533205 -7.794847)
# 1  2021-12-01 00:01:24   POINT (110.3659439086914 -7.794029)
# 2  2021-12-01 00:01:27  POINT (110.36560821533205 -7.794847)
# 3  2021-12-01 00:02:55   POINT (110.3659439086914 -7.794029)
# 4  2021-12-01 00:03:00   POINT (110.3659439086914 -7.794029)
#
#           Kelurahan/Desa  Kecamatan        Kabupaten     tanggal
# 0  Kelurahan Suryatmajan  Danurejan  Kota Yogyakarta  2021-12-01
# 1  Kelurahan Suryatmajan  Danurejan  Kota Yogyakarta  2021-12-01
# 2  Kelurahan Suryatmajan  Danurejan  Kota Yogyakarta  2021-12-01
# 3  Kelurahan Suryatmajan  Danurejan  Kota Yogyakarta  2021-12-01
# 4  Kelurahan Suryatmajan  Danurejan  Kota Yogyakarta  2021-12-01

# %%
def count_maid(data):
    filtered_data = data.copy()
    
    # Ganti 'datetime_wib' sesuai nama kolom datetime di data-mu
    filtered_data['datetime_wib'] = pd.to_datetime(filtered_data['datetime_wib'])
    filtered_data['tanggal'] = filtered_data['datetime_wib'].dt.date

    # Hitung jumlah 'maid' unik per hari
    jumlah_maid_unik_per_hari = filtered_data.groupby('tanggal')['maid'].nunique()

    # Print hasilnya
    # print("Jumlah ID user unik: ", data['maid'].nunique())
    maid = data['maid'].nunique()
    return(maid)
#     print(jumlah_maid_unik_per_hari)

# %%
def bar_chart(data):
    filtered_data = data.copy()

    # Hapus duplikat 'maid' berdasarkan tanggal
    filtered_data_unique_maid = filtered_data.drop_duplicates(subset=['tanggal', 'maid'])

    # Hitung jumlah unik per hari
    jumlah_unik_per_hari = filtered_data_unique_maid.groupby('tanggal').size()

    # Plotting
    plt.figure(figsize=(10, 6))
    jumlah_unik_per_hari.plot(kind='bar', color='skyblue')
    maid = count_maid(data)
    plt.title(f'Jumlah Data Maid unik per Hari: {maid}')
    plt.xlabel('Tanggal')
    plt.ylabel('Jumlah Data Unik')
    plt.xticks(rotation=75)
    plt.show()

# %%
def create_plot(data):
    # Ambil baris pertama dari DataFrame
    first_row = data.iloc[0]

    # Ambil nilai latitude dan longitude dari baris pertama
    latitude = first_row['latitude']
    longitude = first_row['longitude']
    
    m = folium.Map(location=[latitude, longitude], zoom_start=25)

    # Create a PolyLine to connect the points
#     locations = data[['lat', 'lng']].values.tolist()
#     folium.PolyLine(
#         locations=locations,
#         color='red',  # Color of the line
#         weight=2,  # Thickness of the line
#         opacity=1,  # Opacity of the line
#     ).add_to(m)

    # Add CircleMarkers for each point
    for index, row in data.iterrows():
        folium.CircleMarker(
            location=[row["latitude"], row["longitude"]],
            radius=5,  # Marker size
            color="blue",  # Marker color
            fill=True,
            fill_color="blue",  # Fill color of the marker
            fill_opacity=0.7,  # Opacity of the marker fill
            popup=f"User ID: {row['maid']}<br>Latitude: {row['latitude']}<br>Longitude: {row['longitude']}",
        ).add_to(m)
    
    return m

# %%
def create_pivot(data):
    df1_1 = data.copy()
    df1_pivot = df1_1['maid'].groupby(df1_1['tanggal']).value_counts()
    pivot = df1_pivot.unstack().fillna(0).astype(int)

    total_counts = pivot.sum(axis=0)
    sorted_columns = total_counts.sort_values(ascending=False).index
    pivot_sorted = pivot[sorted_columns]
    return pivot_sorted

# %%
def remove_stops(gps, stops):
    stops_df = stops.copy()
    gps_df = gps.copy()

    # Convert datetime columns to datetime objects
    stops_df['datetime_wib'] = pd.to_datetime(stops_df['datetime_wib'])
    stops_df['leaving_datetime'] = pd.to_datetime(stops_df['leaving_datetime'])
    gps_df['datetime_wib'] = pd.to_datetime(gps_df['datetime_wib'])

    # Iterate through each row in Stops DataFrame
    for index, row in stops_df.iterrows():
        uid = row['maid']
        start_time = row['datetime_wib']
        end_time = row['leaving_datetime']

        # Filter GPS DataFrame based on UID and time range
        filtered_gps_df = gps_df[(gps_df['maid'] == uid) & (gps_df['datetime_wib'] >= start_time) & (gps_df['datetime_wib'] < end_time)]
        # Remove corresponding rows from GPS DataFrame
        gps_df = gps_df.drop(filtered_gps_df.index)
    
    # Reset index of GPS DataFrame
    gps_df = gps_df.reset_index(drop=True)

    # Resulting GPS DataFrame without eliminated data
    print("Number of points dropped from original data: %d" %(len(gps) - len(gps_df)))
    
    return gps_df

# %%
def third_preprocessing(df):
    # 1. Noise filtering >200 kmh
    df1 = df.copy()

    df1['datetime_wib'].astype(str)
    tdf = skmob.TrajDataFrame(df1, latitude='latitude', longitude='longitude', user_id='maid', datetime='datetime_wib')
    ftdf = filtering.filter(tdf, max_speed_kmh=200.)
    temp = ftdf.copy()
    df2 = pd.DataFrame(temp)
    df2.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

    # 2. Exclude stop points for time threshold <5min and spatial threshold <100meter
    stdf = detection.stay_locations(ftdf, minutes_for_a_stop=5.0, spatial_radius_km=0.1, leaving_time=True)
    temp = stdf.copy()
    stdf_df = pd.DataFrame(temp)
    stdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

    df3 = remove_stops(df2, stdf_df)    
    
    # 3. Trajectory compression
#     df3_tdf = skmob.TrajDataFrame(df3, latitude='latitude', longitude='longitude', user_id='maid', datetime='datetime_wib')
#     ctdf = compression.compress(df3_tdf, spatial_radius_km = 0.01)
#     temp = ctdf.copy()
#     ctdf_df = pd.DataFrame(temp)
#     ctdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

    return df3

# %%
import pandas as pd
import skmob 
from skmob.preprocessing import detection

def traj(data):    
    data['datetime_wib'] = pd.to_datetime(data['datetime_wib'])

    tdf = skmob.TrajDataFrame(data, latitude='latitude', longitude='longitude', datetime='datetime_wib', user_id='maid')

    stays = detection.stay_locations(
        tdf, 
        spatial_radius_km=0.2,
        minutes_for_a_stop=5,
        leaving_time=True)
    stays = pd.DataFrame(stays)
    stays.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

    return stays

# %%
dataA = pd.DataFrame({'maid': [1] * (8),
                     'latitude': [2] * 3 + [3, 3] + [1] * 3,  
                     'longitude': [2] * 3 + [3, 3] + [1] * 3,
                     'datetime_wib': ['2018-01-01 ' + f'00:{x}' for x in [20, 21, 22, 23, 24, 25, 26, 27]]})


b = traj(dataA)
b
# Out:
# Empty DataFrame
# Columns: [maid, latitude, longitude, datetime_wib, leaving_datetime]
# Index: []

# %%
data = pd.DataFrame({'maid': [1] * (13),
                     'latitude': [1] * 5  + [2] * 3 + [3, 3] + [1] * 3,  
                     'longitude': [1] * 5  + [2] * 3 + [3, 3] + [1] * 3,
                     'datetime_wib': ['2018-01-01 ' + f'00:{x}' for x in [0, 1, 2, 3, 6, 20, 21, 22, 23, 24, 25, 26, 27]]})
stays = traj(data)
data1 = remove_stops(data, stays)

stays1 = traj(data1)
data2 = remove_stops(data1, stays1)

stays2 = traj(data2)
data3 = remove_stops(data2, stays2)
print(data)
print(data1)
print(data2)
# Out:
# Number of points dropped from original data: 5
# Number of points dropped from original data: 0
# Number of points dropped from original data: 0
#     maid  latitude  longitude        datetime_wib
# 0      1         1          1 2018-01-01 00:00:00
# 1      1         1          1 2018-01-01 00:01:00
# 2      1         1          1 2018-01-01 00:02:00
# 3      1         1          1 2018-01-01 00:03:00
# 4      1         1          1 2018-01-01 00:06:00
# 5      1         2          2 2018-01-01 00:20:00
# 6      1         2          2 2018-01-01 00:21:00
# 7      1         2          2 2018-01-01 00:22:00
# 8      1         3          3 2018-01-01 00:23:00
# 9      1         3          3 2018-01-01 00:24:00
# 10     1         1          1 2018-01-01 00:25:00
# 11     1         1          1 2018-01-01 00:26:00
# 12     1         1          1 2018-01-01 00:27:00
#    maid  latitude  longitude        datetime_wib
# 0     1         2          2 2018-01-01 00:20:00
# 1     1         2          2 2018-01-01 00:21:00
# 2     1         2          2 2018-01-01 00:22:00
# 3     1         3          3 2018-01-01 00:23:00
# 4     1         3          3 2018-01-01 00:24:00
# 5     1         1          1 2018-01-01 00:25:00
# 6     1         1          1 2018-01-01 00:26:00
# 7     1         1          1 2018-01-01 00:27:00
#    maid  latitude  longitude        datetime_wib
# 0     1         2          2 2018-01-01 00:20:00
# 1     1         2          2 2018-01-01 00:21:00
# 2     1         2          2 2018-01-01 00:22:00
# 3     1         3          3 2018-01-01 00:23:00
# 4     1         3          3 2018-01-01 00:24:00
# 5     1         1          1 2018-01-01 00:25:00
# 6     1         1          1 2018-01-01 00:26:00
# 7     1         1          1 2018-01-01 00:27:00

# %%
import skmob
import pandas as pd
from skmob.preprocessing import compression
# read the trajectory data (GeoLife)
url = skmob.utils.constants.GEOLIFE_SAMPLE
df = pd.read_csv(url, sep=',', compression='gzip')
tdf = skmob.TrajDataFrame(df, latitude='lat', longitude='lng', user_id='user', datetime='datetime')
tdf_df = pd.DataFrame(tdf)
tdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)
# print(tdf_df.head(100))

# compress the trajectory using a spatial radius of 0.2 km
ctdf = compression.compress(tdf, spatial_radius_km=0.2)
ctdf_df = pd.DataFrame(ctdf)
ctdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

# ctdf_df.head()

# %%
# create_plot(tdf_df[:500])

# %%
# create_plot(ctdf_df[:30])

# %%
path = '../DataGPS_Affandi/filter2_affandi_des.csv'
daf = pd.read_csv(path)
daf1 = third_preprocessing(daf)
daf2 = third_preprocessing(daf1)
daf3 = third_preprocessing(daf2)
daf4 = third_preprocessing(daf3)
create_plot(daf4)
# Out:
# Number of points dropped from original data: 4096
# Number of points dropped from original data: 18
# Number of points dropped from original data: 2
# Number of points dropped from original data: 0
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_dc26de54fa47710927f6e5f24ed1f451 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_dc26de54fa47710927f6e5f24ed1f451&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_dc26de54fa47710927f6e5f24ed1f451 = L.map(
#                 &quot;map_dc26de54fa47710927f6e5f24ed1f451&quot;,
#                 {
#                     center: [-7.758315, 110.39543385192871],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e70b3073ed1dd5ab980ef703cd70bf2f = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_dc26de54fa47710927f6e5f24ed1f451);
#
#
#             var circle_marker_5c24c30b28a29779b60c209ce1a268b3 = L.circleMarker(
#                 [-7.758315, 110.39543385192871],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dc26de54fa47710927f6e5f24ed1f451);
#
#
#         var popup_1d2e6e8dc206bf52a9be9abbd9f15ad8 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_eefe3e539396100583cf135070558c5b = $(`&lt;div id=&quot;html_eefe3e539396100583cf135070558c5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 025509a7-a27d-4770-a34d-b7db0cbd410a&lt;br&gt;Latitude: -7.758315&lt;br&gt;Longitude: 110.39543385192871&lt;/div&gt;`)[0];
#                 popup_1d2e6e8dc206bf52a9be9abbd9f15ad8.setContent(html_eefe3e539396100583cf135070558c5b);
#
#
#
#         circle_marker_5c24c30b28a29779b60c209ce1a268b3.bindPopup(popup_1d2e6e8dc206bf52a9be9abbd9f15ad8)
#         ;
#
#
#
#
#             var circle_marker_a2231e1795c8139669bceea2656b21de = L.circleMarker(
#                 [-7.763202, 110.3937759399414],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dc26de54fa47710927f6e5f24ed1f451);
#
#
#         var popup_d91afd304ecb8ee47da9f74d813c8820 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_4476b40e1f7a85dfd32052775055ebff = $(`&lt;div id=&quot;html_4476b40e1f7a85dfd32052775055ebff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 070e4c4c-b593-49b4-b88e-0d04b39589d4&lt;br&gt;Latitude: -7.763202&lt;br&gt;Longitude: 110.3937759399414&lt;/div&gt;`)[0];
#                 popup_d91afd304ecb8ee47da9f74d813c8820.setContent(html_4476b40e1f7a85dfd32052775055ebff);
#
#
#
#         circle_marker_a2231e1795c8139669bceea2656b21de.bindPopup(popup_d91afd304ecb8ee47da9f74d813c8820)
#         ;
#
#
#
#
#             var circle_marker_88f9e95fbd06eb9d996d660a5e50621d = L.circleMarker(
#                 [-7.761695, 110.39419555664062],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_dc26de54fa47710927f6e5f24ed1f451);
#
#
#         var popup_1c3cfbcfb746cea36a9dbba50adfa234 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_69ba40f14ded2a26c70a8da3089ed07c = $(`&lt;div id=&quot;html_69ba40f14ded2a26c70a8da3089ed07c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0b0a793a-4853-40f2-9255-fcf91aa9865e&lt;br&gt;Latitude: -7.761695&lt;br&gt;Longitude: 110.39419555664062&lt;/div&gt;`)[0];
#                 popup_1c3cfbcfb746cea36a9dbba50adfa234.setContent(html_69ba40f14ded2a26c70a8da3089ed07c);
#
#
#
#         circle_marker_88f9e95fbd06eb9d996d660a5e50621d.bindPopup(popup_1c3cfbcfb746cea36a9dbba50adfa234)
#         ;
#
#
#
#
#             var circle_marker_1471b72841d17b04ce465e2fdb527fb9 = L.circleMarker(

# %%
path = '../DataGPS_Affandi/filter2_affandi_des.csv'
dn = pd.read_csv(path)
tdf = skmob.TrajDataFrame(dn, latitude='latitude', longitude='longitude', user_id='maid', datetime='datetime_wib')
stdf = detection.stay_locations(tdf, stop_radius_factor=0.5, minutes_for_a_stop=5.0, spatial_radius_km=0.1, leaving_time=True)
stdf_df = pd.DataFrame(stdf)
stdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)
stdf_df
# Out:
#                                      maid  latitude   longitude  \
# 0    00071ae2-d9dc-4e14-b3fc-9f8a818ee767 -7.758710  110.394890
# 1    000e5174-be83-47b9-86df-509ea9133e6a -7.759088  110.394512
# 2    00cba227-d6b8-4518-ab6c-8c3ac3ded8b7 -7.761690  110.393677
# 3    017eeb9e-f114-4a24-948e-83816ca6336b -7.758110  110.395989
# 4    01a1e442-8039-4bf5-8559-2e09c72fa1f2 -7.760860  110.394820
# ..                                    ...       ...         ...
# 427  fe3cd61b-e677-4a77-8bde-b288a47fe51a -7.760225  110.394264
# 428  fe7c9435-3235-4ac4-857b-df807a40421b -7.760890  110.394615
# 14  7a28b4f0-2c17-425f-b480-b237bb8aab48
# 15  a36ea4b5-8ee8-4f16-9d80-307e39a7aeba
# 16  a36ea4b5-8ee8-4f16-9d80-307e39a7aeba
# 17  a36ea4b5-8ee8-4f16-9d80-307e39a7aeba
# 18  a36ea4b5-8ee8-4f16-9d80-307e39a7aeba
# 19  c400d419-24c8-4119-b759-2c54ccd46d94
# 20  c400d419-24c8-4119-b759-2c54ccd46d94
# 21  c400d419-24c8-4119-b759-2c54ccd46d94
# 22  f00c19e5-b193-4825-b174-f1e229447944

# %%
stdf_maid_1
# Out:
#                                     maid  latitude   longitude  \
# 22  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759155  110.395413
# 23  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759015  110.395115
# 24  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759200  110.394768
# 25  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759165  110.395317
#
#           datetime_wib                            geometry Kelurahan/Desa  \
# 22 2021-12-06 15:38:11          POINT (110.39541 -7.75915)   Condongcatur
# 23 2021-12-06 17:44:14  POINT (110.3951187133789 -7.75902)   Condongcatur
# 24 2021-12-12 09:18:17          POINT (110.39475 -7.75916)   Condongcatur
# 25 2021-12-12 10:19:30          POINT (110.39542 -7.75909)   Condongcatur
#
#    Kecamatan Kabupaten     tanggal    leaving_datetime
# 22     Depok    Sleman  2021-12-06 2021-12-06 17:41:05
# 23     Depok    Sleman  2021-12-06 2021-12-12 09:18:17
# 24     Depok    Sleman  2021-12-12 2021-12-12 10:19:30
# 25     Depok    Sleman  2021-12-12 2021-12-15 19:11:38

# %%
daf_maid = daf[(daf["maid"] == "0bfd22ec-9aee-4a38-939e-6ca3022ef392")]
create_plot(daf_maid)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_73ae61c995d661ee9d0bf8c31c0750b3 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_73ae61c995d661ee9d0bf8c31c0750b3&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_73ae61c995d661ee9d0bf8c31c0750b3 = L.map(
#                 &quot;map_73ae61c995d661ee9d0bf8c31c0750b3&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f724e16f8ba3d6962b87265acef92bcf = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_73ae61c995d661ee9d0bf8c31c0750b3);
#
#
#             var circle_marker_f80d9a0789029c6c541f64b3ec2622f2 = L.circleMarker(
#                 [-7.76245, 110.39356231689452],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73ae61c995d661ee9d0bf8c31c0750b3);
#
#
#         var popup_9fdceec0fc8626dd43f2b55c85f98f86 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_442e05ca41adf42c95b601ce1c099076 = $(`&lt;div id=&quot;html_442e05ca41adf42c95b601ce1c099076&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.76245&lt;br&gt;Longitude: 110.39356231689452&lt;/div&gt;`)[0];
#                 popup_9fdceec0fc8626dd43f2b55c85f98f86.setContent(html_442e05ca41adf42c95b601ce1c099076);
#
#
#
#         circle_marker_f80d9a0789029c6c541f64b3ec2622f2.bindPopup(popup_9fdceec0fc8626dd43f2b55c85f98f86)
#         ;
#
#
#
#
#             var circle_marker_ea1811e8edfed0250edc65c2315c4eac = L.circleMarker(
#                 [-7.76245, 110.39356],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73ae61c995d661ee9d0bf8c31c0750b3);
#
#
#         var popup_af2852b45b7b9cba160fd5128ba56523 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d4044958ca6e0efb1be12f426161559b = $(`&lt;div id=&quot;html_d4044958ca6e0efb1be12f426161559b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.76245&lt;br&gt;Longitude: 110.39356&lt;/div&gt;`)[0];
#                 popup_af2852b45b7b9cba160fd5128ba56523.setContent(html_d4044958ca6e0efb1be12f426161559b);
#
#
#
#         circle_marker_ea1811e8edfed0250edc65c2315c4eac.bindPopup(popup_af2852b45b7b9cba160fd5128ba56523)
#         ;
#
#
#
#
#             var circle_marker_7deb9bc1af819e71441e5d76e478c434 = L.circleMarker(
#                 [-7.75995, 110.39482879638672],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_73ae61c995d661ee9d0bf8c31c0750b3);
#
#
#         var popup_2a752e17f684ac9d11792ea82238f707 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_e7a54b5e59c9ef384de49db883458b9d = $(`&lt;div id=&quot;html_e7a54b5e59c9ef384de49db883458b9d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.75995&lt;br&gt;Longitude: 110.39482879638672&lt;/div&gt;`)[0];
#                 popup_2a752e17f684ac9d11792ea82238f707.setContent(html_e7a54b5e59c9ef384de49db883458b9d);
#
#
#
#         circle_marker_7deb9bc1af819e71441e5d76e478c434.bindPopup(popup_2a752e17f684ac9d11792ea82238f707)
#         ;
#
#
#
#
#             var circle_marker_d38d9ed2d885c7aca4a5118fffb8e3df = L.circleMarker(
#                 [-7.75996, 110.394836

# %%
stdf_maid_1 = stdf1[(stdf1["maid"] == "0bfd22ec-9aee-4a38-939e-6ca3022ef392")]
create_plot(stdf_maid_1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9a34da195a1ba2a4f037607b20f13a7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9a34da195a1ba2a4f037607b20f13a7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9a34da195a1ba2a4f037607b20f13a7 = L.map(
#                 &quot;map_d9a34da195a1ba2a4f037607b20f13a7&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efa9885ecef9e62a08f35818c8653599 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_d9a34da195a1ba2a4f037607b20f13a7);
#
#
#             var circle_marker_1fd6e6f8d9a3e816939fbac624aca3b3 = L.circleMarker(
#                 [-7.759155, 110.39541312988281],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9a34da195a1ba2a4f037607b20f13a7);
#
#
#         var popup_e31d1db1370e957b700c8b2b5bdb8b6e = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b81b025f64d8dcdb170d1dbb324c08e6 = $(`&lt;div id=&quot;html_b81b025f64d8dcdb170d1dbb324c08e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.759155&lt;br&gt;Longitude: 110.39541312988281&lt;/div&gt;`)[0];
#                 popup_e31d1db1370e957b700c8b2b5bdb8b6e.setContent(html_b81b025f64d8dcdb170d1dbb324c08e6);
#
#
#
#         circle_marker_1fd6e6f8d9a3e816939fbac624aca3b3.bindPopup(popup_e31d1db1370e957b700c8b2b5bdb8b6e)
#         ;
#
#
#
#
#             var circle_marker_f04b1dc6a19d86cd9caa69bd6463e0ea = L.circleMarker(
#                 [-7.759015, 110.39511489868164],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_d9a34da195a1ba2a4f037607b20f13a7);
#
#
#         var popup_1b1e402fbf9da70231e61d8d36689e2b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html
# 1999   Condongcatur     Depok    Sleman  2021-12-12
# 2000   Condongcatur     Depok    Sleman  2021-12-12
# 2316   Condongcatur     Depok    Sleman  2021-12-15
# 2317   Condongcatur     Depok    Sleman  2021-12-15
# 2318   Condongcatur     Depok    Sleman  2021-12-15
# 2319   Condongcatur     Depok    Sleman  2021-12-15
# 2320   Condongcatur     Depok    Sleman  2021-12-15
# 2321   Condongcatur     Depok    Sleman  2021-12-15
# 2322   Condongcatur     Depok    Sleman  2021-12-15
# 2323   Condongcatur     Depok    Sleman  2021-12-15

# %%
stdf_maid_2
# Out:
#                                    maid  latitude   longitude  \
# 0  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759955  110.394833
# 1  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.757950  110.395866
#
#          datetime_wib                             geometry Kelurahan/Desa  \
# 0 2021-12-06 15:36:01  POINT (110.39483642578124 -7.75996)   Condongcatur
# 1 2021-12-06 17:41:50           POINT (110.39588 -7.75795)   Condongcatur
#
#   Kecamatan Kabupaten     tanggal    leaving_datetime
# 0     Depok    Sleman  2021-12-06 2021-12-06 17:41:50
# 1     Depok    Sleman  2021-12-06 2021-12-15 19:11:48

# %%
daf_maid_1 = daf1[(daf1["maid"] == "0bfd22ec-9aee-4a38-939e-6ca3022ef392")]
create_plot(daf_maid_1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9e31df04bc728bf46759e0f1d19f64e4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9e31df04bc728bf46759e0f1d19f64e4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9e31df04bc728bf46759e0f1d19f64e4 = L.map(
#                 &quot;map_9e31df04bc728bf46759e0f1d19f64e4&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_15f1fb78100f3c104372b2b62b82c335 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9e31df04bc728bf46759e0f1d19f64e4);
#
#
#             var circle_marker_6e69b16a02d5ef9dc813cc0e48a7400a = L.circleMarker(
#                 [-7.76245, 110.39356115844726],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e31df04bc728bf46759e0f1d19f64e4);
#
#
#         var popup_529067f7fae451ccd1096c00da97a930 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_715243eb3fb8798d6e80b9966f294192 = $(`&lt;div id=&quot;html_715243eb3fb8798d6e80b9966f294192&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.76245&lt;br&gt;Longitude: 110.39356115844726&lt;/div&gt;`)[0];
#                 popup_529067f7fae451ccd1096c00da97a930.setContent(html_715243eb3fb8798d6e80b9966f294192);
#
#
#
#         circle_marker_6e69b16a02d5ef9dc813cc0e48a7400a.bindPopup(popup_529067f7fae451ccd1096c00da97a930)
#         ;
#
#
#
#
#             var circle_marker_e5a3bdbd0a3339d504b6c261f6556add = L.circleMarker(
#                 [-7.759955, 110.39483261108398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e31df04bc728bf46759e0f1d19f64e4);
#
#
#         var popup_10145fbc08ccfeedb2bdc99e08ed1d55 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_50057d322ecb77dbcba58ba2eb6ad32f = $(`&lt;div id=&quot;html_50057d322ecb77dbcba58ba2eb6ad32f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.759955&lt;br&gt;Longitude: 110.39483261108398&lt;/div&gt;`)[0];
#                 popup_10145fbc08ccfeedb2bdc99e08ed1d55.setContent(html_50057d322ecb77dbcba58ba2eb6ad32f);
#
#
#
#         circle_marker_e5a3bdbd0a3339d504b6c261f6556add.bindPopup(popup_10145fbc08ccfeedb2bdc99e08ed1d55)
#         ;
#
#
#
#
#             var circle_marker_9a932dfbded87f83a61625691c483064 = L.circleMarker(
#                 [-7.75795, 110.39586639404295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_9e31df04bc728bf46759e0f1d19f64e4);
#
#
#         var popup_1ea219c22b87b712d7bb0990dd633d35 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_13e0cb901a778071cc374c615f5de2fa = $(`&lt;div id=&quot;html_13e0cb901a778071cc374c615f5de2fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.75795&lt;br&gt;Longitude: 110.39586639404295&lt;/div&gt;`)[0];
#                 popup_1ea219c22b87b712d7bb0990dd633d35.setContent(html_13e0cb901a778071cc374c615f5de2fa);
#
#
#
#         circle_marker_9a932dfbded87f83a61625691c483064.bindPopup(popup_1ea219c22b87b712d7bb0990dd633d35)
#         ;
#
#
#
#
#             var circle_marker_13580a6faf7a984cbf56e1d6b7f75f3e = L.circleMarker(
#                 [

# %%
stdf_maid_2 = stdf2[(stdf2["maid"] == "0bfd22ec-9aee-4a38-939e-6ca3022ef392")]
create_plot(stdf_maid_2)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3914d5deda8c45d2853d8d11167ad0a0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3914d5deda8c45d2853d8d11167ad0a0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3914d5deda8c45d2853d8d11167ad0a0 = L.map(
#                 &quot;map_3914d5deda8c45d2853d8d11167ad0a0&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1121fbb7fda40f697fefd9674e82268d = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_3914d5deda8c45d2853d8d11167ad0a0);
#
#
#             var circle_marker_fd19f4481c865d7dffb905daaa71deed = L.circleMarker(
#                 [-7.759955, 110.39483261108398],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3914d5deda8c45d2853d8d11167ad0a0);
#
#
#         var popup_6d2fe4a2553832ac88d51e346a339f85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d6dc8075f9caac9bd5fb74a8a834a0e0 = $(`&lt;div id=&quot;html_d6dc8075f9caac9bd5fb74a8a834a0e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.759955&lt;br&gt;Longitude: 110.39483261108398&lt;/div&gt;`)[0];
#                 popup_6d2fe4a2553832ac88d51e346a339f85.setContent(html_d6dc8075f9caac9bd5fb74a8a834a0e0);
#
#
#
#         circle_marker_fd19f4481c865d7dffb905daaa71deed.bindPopup(popup_6d2fe4a2553832ac88d51e346a339f85)
#         ;
#
#
#
#
#             var circle_marker_6865ae440cc5b05d7aa054bfe1a27eee = L.circleMarker(
#                 [-7.75795, 110.39586639404295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_3914d5deda8c45d2853d8d11167ad0a0);
#
#
#         var popup_3ed85b35a50ccf16929ff81dfa46bbd1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b3c424a2fc0e4ed67426d5a2022a3a27 = $(`&lt;div id=&quot;html_b3c424a2fc0e4ed67426d5a2022a3a27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt
# 144     Depok    Sleman  2021-12-06
# 179     Depok    Sleman  2021-12-15
# 180     Depok    Sleman  2021-12-15
# 181     Depok    Sleman  2021-12-15
# 182     Depok    Sleman  2021-12-15
# 183     Depok    Sleman  2021-12-15
# 184     Depok    Sleman  2021-12-15
# 185     Depok    Sleman  2021-12-15

# %%
stdf_maid_3
# Out:
#                                    maid  latitude   longitude  \
# 0  0bfd22ec-9aee-4a38-939e-6ca3022ef392  -7.76245  110.393561
#
#          datetime_wib                    geometry Kelurahan/Desa Kecamatan  \
# 0 2021-12-06 15:34:07  POINT (110.39356 -7.76245)   Caturtunggal     Depok
#
#   Kabupaten     tanggal    leaving_datetime
# 0    Sleman  2021-12-06 2021-12-15 19:13:31

# %%
stdf_maid_3 = stdf3[(stdf3["maid"] == "0bfd22ec-9aee-4a38-939e-6ca3022ef392")]
create_plot(stdf_maid_3)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b5efbbd2ecfcd21a25ec191bbb5c7fe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b5efbbd2ecfcd21a25ec191bbb5c7fe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b5efbbd2ecfcd21a25ec191bbb5c7fe6 = L.map(
#                 &quot;map_b5efbbd2ecfcd21a25ec191bbb5c7fe6&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e85eded6243ac0f6b6cb5d80bc80afa8 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b5efbbd2ecfcd21a25ec191bbb5c7fe6);
#
#
#             var circle_marker_44ed2101c9d9d40dd2a673415e116ee7 = L.circleMarker(
#                 [-7.76245, 110.39356115844726],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_b5efbbd2ecfcd21a25ec191bbb5c7fe6);
#
#
#         var popup_d64a2decb2d7971350d68b623439ba97 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5fd6c379ad57fc69d4d3fa9f1cc6a028 = $(`&lt;div id=&quot;html_5fd6c379ad57fc69d4d3fa9f1cc6a028&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 0bfd22ec-9aee-4a38-939e-6ca3022ef392&lt;br&gt;Latitude: -7.76245&lt;br&gt;Longitude: 110.39356115844726&lt;/div&gt;`)[0];
#                 popup_d64a2decb2d7971350d68b623439ba97.setContent(html_5fd6c379ad57fc69d4d3fa9f1cc6a028);
#
#
#
#         circle_marker_44ed2101c9d9d40dd2a673415e116ee7.bindPopup(popup_d64a2decb2d7971350d68b623439ba97)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stdf_maid = stdf1[(stdf1["maid"] == "d04a5c30-74d8-400f-b79c-15e3afae0061") & (stdf1["tanggal"] == "2021-12-14") ]
stdf_maid
# Out:
#                                      maid  latitude   longitude  \
# 348  d04a5c30-74d8-400f-b79c-15e3afae0061 -7.760792  110.393913
# 349  d04a5c30-74d8-400f-b79c-15e3afae0061 -7.760110  110.394897
#
#            datetime_wib                              geometry Kelurahan/Desa  \
# 348 2021-12-14 08:02:34  POINT (110.3938980102539 -7.7607017)   Condongcatur
# 349 2021-12-14 08:11:04  POINT (110.39490509033205 -7.760108)   Condongcatur
#
#     Kecamatan Kabupaten     tanggal    leaving_datetime
# 348     Depok    Sleman  2021-12-14 2021-12-14 08:11:04
# 349     Depok    Sleman  2021-12-14 2021-12-18 16:39:34

# %%
create_plot(stdf1)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0b6ff45a13541d465ee33e6c27329bb2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0b6ff45a13541d465ee33e6c27329bb2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0b6ff45a13541d465ee33e6c27329bb2 = L.map(
#                 &quot;map_0b6ff45a13541d465ee33e6c27329bb2&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_14795002d41e9abe2f50b5a394c7ab55 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_0b6ff45a13541d465ee33e6c27329bb2);
#
#
#             var circle_marker_78ef7f23dfe8739116cd2046323937c2 = L.circleMarker(
#                 [-7.75871, 110.39488983154295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b6ff45a13541d465ee33e6c27329bb2);
#
#
#         var popup_e6482352605b286e968c128ab097e6c0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_532a5bbbc4a68bbeebee59c397016cd5 = $(`&lt;div id=&quot;html_532a5bbbc4a68bbeebee59c397016cd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 00071ae2-d9dc-4e14-b3fc-9f8a818ee767&lt;br&gt;Latitude: -7.75871&lt;br&gt;Longitude: 110.39488983154295&lt;/div&gt;`)[0];
#                 popup_e6482352605b286e968c128ab097e6c0.setContent(html_532a5bbbc4a68bbeebee59c397016cd5);
#
#
#
#         circle_marker_78ef7f23dfe8739116cd2046323937c2.bindPopup(popup_e6482352605b286e968c128ab097e6c0)
#         ;
#
#
#
#
#             var circle_marker_2cf055bd29c61e22620a0612dba1ebdb = L.circleMarker(
#                 [-7.7590883, 110.39451181030273],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b6ff45a13541d465ee33e6c27329bb2);
#
#
#         var popup_971c7ae8fbc4ef52a03559ad38fc50c7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3288b03b3e52f33fffad3c869f3a898d = $(`&lt;div id=&quot;html_3288b03b3e52f33fffad3c869f3a898d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 000e5174-be83-47b9-86df-509ea9133e6a&lt;br&gt;Latitude: -7.7590883&lt;br&gt;Longitude: 110.39451181030273&lt;/div&gt;`)[0];
#                 popup_971c7ae8fbc4ef52a03559ad38fc50c7.setContent(html_3288b03b3e52f33fffad3c869f3a898d);
#
#
#
#         circle_marker_2cf055bd29c61e22620a0612dba1ebdb.bindPopup(popup_971c7ae8fbc4ef52a03559ad38fc50c7)
#         ;
#
#
#
#
#             var circle_marker_8f9c6451a4b80118bbaf5163782f8dcb = L.circleMarker(
#                 [-7.76169, 110.3936767578125],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_0b6ff45a13541d465ee33e6c27329bb2);
#
#
#         var popup_c4af2ff48a2a860462edd01c42c721c6 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_ab8af29780fa0e652dd7dee098a449fe = $(`&lt;div id=&quot;html_ab8af29780fa0e652dd7dee098a449fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 00cba227-d6b8-4518-ab6c-8c3ac3ded8b7&lt;br&gt;Latitude: -7.76169&lt;br&gt;Longitude: 110.3936767578125&lt;/div&gt;`)[0];
#                 popup_c4af2ff48a2a860462edd01c42c721c6.setContent(html_ab8af29780fa0e652dd7dee098a449fe);
#
#
#
#         circle_marker_8f9c6451a4b80118bbaf5163782f8dcb.bindPopup(popup_c4af2ff48a2a860462edd01c42c721c6)
#         ;
#
#
#
#
#             var circle_marker_46ca6d8409b747891a73168952c04934 = L.circleMarker(
#                 [

# %%
create_plot(stdf_maid)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_32e0eecd968295fc2702aea576960f78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_32e0eecd968295fc2702aea576960f78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_32e0eecd968295fc2702aea576960f78 = L.map(
#                 &quot;map_32e0eecd968295fc2702aea576960f78&quot;,
#                 {
#                     center: [-7.75871, 110.39489],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_129ed909dc40a85d799d40cb77d166c3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_32e0eecd968295fc2702aea576960f78);
#
#
#             var circle_marker_d127d29cc74d063a5175bd6539ea33b0 = L.circleMarker(
#                 [-7.760792, 110.39391326904295],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_32e0eecd968295fc2702aea576960f78);
#
#
#         var popup_99aab1063087a3386e1a592c883f885d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d7e357be1cfcccf3e658107f5eae2d13 = $(`&lt;div id=&quot;html_d7e357be1cfcccf3e658107f5eae2d13&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: d04a5c30-74d8-400f-b79c-15e3afae0061&lt;br&gt;Latitude: -7.760792&lt;br&gt;Longitude: 110.39391326904295&lt;/div&gt;`)[0];
#                 popup_99aab1063087a3386e1a592c883f885d.setContent(html_d7e357be1cfcccf3e658107f5eae2d13);
#
#
#
#         circle_marker_d127d29cc74d063a5175bd6539ea33b0.bindPopup(popup_99aab1063087a3386e1a592c883f885d)
#         ;
#
#
#
#
#             var circle_marker_a7bf7bea7e7d2fbdb61418d2c14683c5 = L.circleMarker(
#                 [-7.76011, 110.3948974609375],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_32e0eecd968295fc2702aea576960f78);
#
#
#         var popup_ad0f3ba99eebc797d0ed6ee9e6d2e7a7 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_9d8126ac8684a1abfa5957233316806d = $(`&lt;div id=&quot;html_9d8126ac8684a1abfa5957233316806d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: d04a5c30-74d8-400f-b79c-15e3afae0061&lt;br&gt;Latitude: -7.76011&lt;br&gt;Longitude: 110.3948974609375&lt;/div&gt;`)[0];
#                 popup_ad0f3ba99eebc797d0ed6ee9e6d2e7a7.setContent(html_9d8126ac8684a1abfa5957233316806d);
#
#
#
#         circle_marker_a7bf7bea7e7d2fbdb61418d2c14683c5.bindPopup(popup_ad0f3ba99eebc797d0ed6ee9e6d2e7a7)
#         ;
#
#
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
stdf2
# Out:
#                                    maid  latitude   longitude  \
# 0  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.759955  110.394833
# 1  0bfd22ec-9aee-4a38-939e-6ca3022ef392 -7.757950  110.395866
# 2  2c9ec18b-5a5e-4c09-8cfe-11b6ab6a7881 -7.762875  110.393777
# 3  6656b330-9b8e-4d4e-83aa-5b8e1b1d5493 -7.763105  110.393705
# 4  74ea98ca-a5e7-4d89-b846-eac9cb2c654b -7.758635  110.394817
# 5  7a28b4f0-2c17-425f-b480-b237bb8aab48 -7.763080  110.393707
# 6  a36ea4b5-8ee8-4f16-9d80-307e39a7aeba -7.762098  110.394005
# 7  c400d419-24c8-4119-b759-2c54ccd46d94 -7.759899  110.395004
# 8  f00c19e5-b193-4825-b174-f1e229447944 -7.758655  110.395656
#
#          datetime_wib                              geometry Kelurahan/Desa  \
# 0 2021-12-06 15:36:01   POINT (110.39483642578124 -7.75996)   Condongcatur
# 1 2021-12-06 17:41:50            POINT (110.39588 -7.75795)   Condongcatur
# 2 2021-12-13 09:41:13   POINT (110.39378356933594 -7.76287)   Caturtunggal
# 3 2021-12-18 10:03:50   POINT (110.39373016357422 -7.76276)   Caturtunggal
# 4 2021-12-14 14:23:15    POINT (110.3948211669922 -7.75863)   Condongcatur
# 49      Depok    Sleman  2021-11-08
# 50      Depok    Sleman  2021-11-08
# 51      Depok    Sleman  2021-11-08
# 52      Depok    Sleman  2021-11-08
# 53      Depok    Sleman  2021-11-08
# ..        ...       ...         ...
# 274     Depok    Sleman  2021-11-08
# 275     Depok    Sleman  2021-11-08
# 276     Depok    Sleman  2021-11-08
# 277     Depok    Sleman  2021-11-08
# 278     Depok    Sleman  2021-11-08
#
# [230 rows x 9 columns]

# %% [markdown]
# ## 1. Noise filtering
# We are going to remove the outlier here, for some points that have the velocity of 'the flash' or maybe they were on a flight

# %%
df1 = df.copy()

df1['datetime_wib'].astype(str)
tdf = skmob.TrajDataFrame(df1, latitude='latitude', longitude='longitude', user_id='maid', datetime='datetime_wib')
ftdf = filtering.filter(tdf, max_speed_kmh=200.)
temp = ftdf.copy()
df1 = pd.DataFrame(temp)
df1.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

print('Number of points before filtering: %d' %len(df))
print('Number of points after filtering: %d\n' %(len(df1)))
# Out:
# Number of points before filtering: 38828
# Number of points after filtering: 38823

# %%
print("Unique value for each column:")
print(df1.nunique())
print("\n")

print("Shape before noise filtering: ", df.shape)
print("Shape after noise filtering: ", df1.shape)
# Out:
# Unique value for each column:
# maid               4383
# latitude           4173
# longitude           759
# datetime_wib      38460
# geometry          11350
# Kelurahan/Desa        5
# Kecamatan             4
# Kabupaten             1
# tanggal              31
# dtype: int64
#
#
# Shape before noise filtering:  (38828, 9)
# Shape after noise filtering:  (38823, 9)

# %% [markdown]
# ## 1.1 Explore after noise filtering

# %%
bar_chart(df1)

# %%
df1['maid'].value_counts()
# Out:
# 9a63fd0e-d363-478a-8136-99b1eb82693f    2245
# f501c8a1-e251-4b8c-87fc-9a1a26d2e19d    1983
# 6065d08e-1b9a-45ed-9042-fc0773b25d3a     775
# a2b6a27a-35e9-4735-909b-6cfbafd288ac     551
# 4a2de4fb-2878-41ae-bc12-2890dc0f62b8     514
#                                         ...
# b9f91dc7-e98e-4db6-a1a9-d946e71e8344       2
# 84085ef1-30fc-44a1-b2db-a28cea80e759       2
# b9e3686d-4361-4f35-b5df-e0b208603b65       2
# 840c5677-2922-47a6-8aaa-0c31e11403de       2
# 69205336-4054-4a3a-800f-23037bc73e45       2
# Name: maid, Length: 4383, dtype: int64

# %%
create_pivot(df1)
# Out:
# maid        9a63fd0e-d363-478a-8136-99b1eb82693f  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                    89
# 2021-12-05                                   128
# 2021-12-06                                    76
# 2021-12-07                                    84
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                   158
# 2021-12-14                                     0
# 2021-12-15                                   219
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                   157
# 2021-12-19                                   150
# 2021-12-20                                     0
# 2021-12-21                                   153
# 2021-12-22                                    68
# 2021-12-23                                     7
# 2021-12-24                                   101
# 2021-12-25                                   113
# 2021-12-26                                   135
# 2021-12-27                                   113
# 2021-12-28                                     0
# 2021-12-29                                   208
# 2021-12-30                                   144
# 2021-12-31                                   142
#
# maid        f501c8a1-e251-4b8c-87fc-9a1a26d2e19d  \
# tanggal
# 2021-12-01                                    34
# 2021-12-02                                     0
# 2021-12-03                                    12
# 2021-12-04                                    18
# 2021-12-05                                    20
# 2021-12-06                                    22
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        5fd88d93-817a-4804-a6cd-3392c125e0a9  ...  \
# tanggal                                           ...
# 2021-12-01                                     4  ...
# 2021-12-02                                     0  ...
# 2021-12-03                                     0  ...
# 2021-12-04                                     0  ...
# 2021-12-05                                     0  ...
# 2021-12-06                                     0  ...
# 2021-12-07                                     2  ...
# 2021-12-08                                     0  ...
# 2021-12-09                                     1  ...
# 2021-12-10                                     0  ...
# 2021-12-11                                     4  ...
# 2021-12-12                                     2  ...
# 2021-12-13                                     8  ...
# 2021-12-14                                     4  ...
# 2021-12-15                                     9  ...
# 2021-12-16                                     3  ...
# 2021-12-17                                    21  ...
# 2021-12-18                                    11  ...
# 2021-12-19                                    66  ...
# 2021-12-20                                    11  ...
# 2021-12-21                                    12  ...
# 2021-12-22                                    19  ...
# 2021-12-23                                     2  ...
# 2021-12-24                                     2  ...
# 2021-12-25                                     7  ...
# 2021-12-26                                     0  ...
# 2021-12-27                                     0  ...
# 2021-12-28                                    29  ...
# 2021-12-29                                     4  ...
# 2021-12-30                                     0  ...
# 2021-12-31                                     4  ...
#
# maid        31e3cb72-7c36-40f8-a5f8-f1e6480f1e83  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     2
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        31f0338b-8ce2-4c4b-9578-cc60073cfaac  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     2
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        84023cc6-9052-4a3c-892f-acd277f5080d  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     2
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        56d58bf2-6bfe-42ff-ab2e-946731bd876b  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     2
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        ba13e423-3e6e-4baa-a9b5-98fa147e5e15  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     2
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        b9f91dc7-e98e-4db6-a1a9-d946e71e8344  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     2
#
# maid        84085ef1-30fc-44a1-b2db-a28cea80e759  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     2
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        b9e3686d-4361-4f35-b5df-e0b208603b65  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     1
# 2021-12-21                                     1
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# maid        840c5677-2922-47a6-8aaa-0c31e11403de  \
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     0
# 2021-12-14                                     0
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     2
# 2021-12-31                                     0
#
# maid        69205336-4054-4a3a-800f-23037bc73e45
# tanggal
# 2021-12-01                                     0
# 2021-12-02                                     0
# 2021-12-03                                     0
# 2021-12-04                                     0
# 2021-12-05                                     0
# 2021-12-06                                     0
# 2021-12-07                                     0
# 2021-12-08                                     0
# 2021-12-09                                     0
# 2021-12-10                                     0
# 2021-12-11                                     0
# 2021-12-12                                     0
# 2021-12-13                                     1
# 2021-12-14                                     1
# 2021-12-15                                     0
# 2021-12-16                                     0
# 2021-12-17                                     0
# 2021-12-18                                     0
# 2021-12-19                                     0
# 2021-12-20                                     0
# 2021-12-21                                     0
# 2021-12-22                                     0
# 2021-12-23                                     0
# 2021-12-24                                     0
# 2021-12-25                                     0
# 2021-12-26                                     0
# 2021-12-27                                     0
# 2021-12-28                                     0
# 2021-12-29                                     0
# 2021-12-30                                     0
# 2021-12-31                                     0
#
# [31 rows x 4383 columns]

# %%
plot = df1[(df1['maid'] == '9a63fd0e-d363-478a-8136-99b1eb82693f') & (df1['tanggal'] == '2021-12-29')]
visual = plot.sort_values(by='datetime_wib')
# visual = visual[:10]
visual
# Out:
#                                        maid  latitude   longitude  \
# 26005  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79389  110.365189
# 26006  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79388  110.365189
# 26007  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79387  110.365189
# 26008  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79389  110.365189
# 26009  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79395  110.365181
# ...                                     ...       ...         ...
# 26208  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79399  110.365288
# 26209  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79411  110.364738
# 26210  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79411  110.364731
# 26211  9a63fd0e-d363-478a-8136-99b1eb82693f  -7.79390  110.364750

#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_58f90bc5922535c67e20a76a95fe5e2b);
#
#
#         var popup_5c89c7e1464cd09bd2663f0fc7abfa9d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c3a9dd991f27acaf98fe565634da9975 = $(`&lt;div id=&quot;html_c3a9dd991f27acaf98fe565634da9975&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 9a63fd0e-d363-478a-8136-99b1eb82693f&lt;br&gt;Latitude: -7.79388&lt;br&gt;Longitude: 110.3651885986328&lt;/div&gt;`)[0];
#             popup_5c89c7e1464cd09bd2663f0fc7abfa9d.setContent(html_c3a9dd991f27acaf98fe565634da9975);
#
#
#         circle_marker_38b1de88680e6a9e5b74236692f0551d.bindPopup(popup_5c89c7e1464cd09bd2663f0fc7abfa9d)
#         ;
#
#
#
#
#             var circle_marker_68f98c4757f775df958e9e32d32b1f5f = L.circleMarker(
#                 [-7.7938704, 110.3651885986328],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_58f90bc5922535c67e20a76a95fe5e2b);
#
#
#         var popup_7976cdcc340389419c8aeba0be925e8c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_70bb241a255242500817850e9e926652 = $(`&lt;div id=&quot;html_70bb241a255242500817850e9e926652&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 9a63fd0e-d363-478a-8136-99b1eb82693f&lt;br&gt;Latitude: -7.7938704&lt;br&gt;Longitude: 110.3651885986328&lt;/div&gt;`)[0];
#             popup_7976cdcc340389419c8aeba0be925e8c.setContent(html_70bb241a255242500817850e9e926652);
#
#
#         circle_marker_68f98c4757f775df958e9e32d32b1f5f.bindPopup(popup_7976cdcc340389419c8aeba0be925e8c)
#         ;
#
#
#
#
#             var circle_marker_e78f3ee842e3cbda51ad10f04b2adf64 = L.circleMarker(
#                 [-7.79389, 110.3651885986328],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;:

# %% [markdown]
# ## 2. Stop detection
# Detect the stay locations (or stops) for each individual in a TrajDataFrame. A stop is detected when the individual spends at least minutes_for_a_stop minutes within a distance stop_radius_factor * spatial_radius km from a given trajectory point.

# %% [markdown]
# Based on the paper [4] Traffic Flow Analysis and Prediction Based on GPS Data of Floating Cars.
#
# From their experiment, they set the time threshold value for 5 min, and the spatial threshold value is 100m. So the velocity threshold is set below 5 km/h.

# %%
stdf = detection.stay_locations(ftdf, minutes_for_a_stop=5.0, spatial_radius_km=0.1, leaving_time=True)
temp = stdf.copy()
stdf_df = pd.DataFrame(temp)
stdf_df.rename(columns={'uid': 'maid', 'lat': 'latitude', 'lng':'longitude', 'datetime':'datetime_wib'}, inplace=True)

print('Number of stop points: %d\n' %(len(stdf_df)))
# Out:
# Number of stop points: 4029

# %%
df2 = remove_stops(df1, stdf_df)
# Out:
# Number of points dropped from original data: 35591

# %%
print("Unique value for each column:")
print(df2.nunique())
print("\n")

print("Shape before remove stops: ", df1.shape)
print("Shape after remove stops: ", df2.shape)
# Out:
# Unique value for each column:
# maid              1147
# latitude           930
# longitude          467
# datetime_wib      3229
# geometry          1362
# Kelurahan/Desa       5
# Kecamatan            4
# Kabupaten            1
# tanggal             31
# dtype: int64
#
#
# Shape before remove stops:  (38823, 9)
# Shape after remove stops:  (3232, 9)

# %% [markdown]
# ## 2.1 Explore after remove stops
# Not suprised that more than 80% of the records are stop points :(

# %%
bar_chart(df2)

# %%
df2.head()
# Out:
#                                     maid  latitude   longitude  \
# 21  004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.365000
# 22  004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.364998
# 33  0077b22a-bc83-4dc5-a748-3b16fd4c7893 -7.800784  110.365456
# 34  0077b22a-bc83-4dc5-a748-3b16fd4c7893 -7.800784  110.365456
# 35  00886369-540d-4f73-b4d3-b8b8cdf5f7fb -7.801390  110.365000
#
#           datetime_wib                              geometry  \
# 21 2021-12-26 18:42:55              POINT (110.365 -7.80139)
# 22 2021-12-26 18:43:35   POINT (110.36499786376952 -7.80139)
# 33 2021-12-22 22:46:11  POINT (110.3654556274414 -7.8007836)
# 34 2021-12-22 22:48:16   POINT (110.3654556274414 -7.800784)
# 35 2021-12-02 19:16:21              POINT (110.365 -7.80139)
#
#         Kelurahan/Desa   Kecamatan        Kabupaten     tanggal
# 21  Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-26
# 22  Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-26
# 33  Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-22
# 34  Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-22
# 35  Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-02

# %%
plot = df2[(df2['maid'] == 'f501c8a1-e251-4b8c-87fc-9a1a26d2e19d') & (df2['tanggal'] == '2021-12-28')]
visual = plot.sort_values(by='datetime_wib')

# %%
plot = df2[df2['tanggal'] == '2021-12-01']
visual = plot.sort_values(by='datetime_wib')

# %%
create_plot(visual)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e87da2268905aea9301b253449c2d81e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e87da2268905aea9301b253449c2d81e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e87da2268905aea9301b253449c2d81e = L.map(
#                 &quot;map_e87da2268905aea9301b253449c2d81e&quot;,
#                 {
#                     center: [-7.794847, 110.365608],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 25,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_78863c4d3f9ef86fe2f443e16cf058f3 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_e87da2268905aea9301b253449c2d81e);
#
#
#             var circle_marker_5af7676c91b0ca3949618716a575a4e6 = L.circleMarker(
#                 [-7.80005, 110.36431884765624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e87da2268905aea9301b253449c2d81e);
#
#
#         var popup_00c765303d6b47860e8acf7ccd756b65 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c62bd869fe0190d62d54a99ee6739400 = $(`&lt;div id=&quot;html_c62bd869fe0190d62d54a99ee6739400&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 9949efdd-0c18-4b71-add1-f0f73c2315a5&lt;br&gt;Latitude: -7.80005&lt;br&gt;Longitude: 110.36431884765624&lt;/div&gt;`)[0];
#             popup_00c765303d6b47860e8acf7ccd756b65.setContent(html_c62bd869fe0190d62d54a99ee6739400);
#
#
#         circle_marker_5af7676c91b0ca3949618716a575a4e6.bindPopup(popup_00c765303d6b47860e8acf7ccd756b65)
#         ;
#
#
#
#
#             var circle_marker_caf5190055a2d507057fe246a512f2a0 = L.circleMarker(
#                 [-7.80005, 110.36431884765624],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e87da2268905aea9301b253449c2d81e);
#
#
#         var popup_2876546f11971132dde74737765cbd66 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6dc0596ac47aa3c48bb25c9292ca3dca = $(`&lt;div id=&quot;html_6dc0596ac47aa3c48bb25c9292ca3dca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 9949efdd-0c18-4b71-add1-f0f73c2315a5&lt;br&gt;Latitude: -7.80005&lt;br&gt;Longitude: 110.36431884765624&lt;/div&gt;`)[0];
#             popup_2876546f11971132dde74737765cbd66.setContent(html_6dc0596ac47aa3c48bb25c9292ca3dca);
#
#
#         circle_marker_caf5190055a2d507057fe246a512f2a0.bindPopup(popup_2876546f11971132dde74737765cbd66)
#         ;
#
#
#
#
#             var circle_marker_60fbb124c2f0b8081b97873c52982262 = L.circleMarker(
#                 [-7.80139, 110.36499786376952],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;blue&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_e87da2268905aea9301b253449c2d81e);
#
#
#         var popup_6be35dc947b051371a8aeae646e14ce9 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_069d415565197e6f3d48d10982f32496 = $(`&lt;div id=&quot;html_069d415565197e6f3d48d10982f32496&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;User ID: 1aa15bbd-21a7-496f-88a3-1a3dd1be6478&lt;br&gt;Latitude: -7.80139&lt;br&gt;Longitude: 110.36499786376952&lt;/div&gt;`)[0];
#             popup_6be35dc947b051371a8aeae646e14ce9.setContent(html_069d415565197e6f3d48d10982f32496);
#
#
#         circle_marker_60fbb124c2f0b8081b97873c52982262.bindPopup(popup_6be35dc947b051371a8aeae646e14ce9)
#         ;
#
#
#
#
#             var circle_marker_1d773454984e36536b1945aee50806b8 = L.circleMarker(
#                 [-7.80139, 110.36499786376952],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quo

# %%
# Menghitung jumlah kemunculan setiap UID pada setiap tanggal
a = df2.copy()

count_per_day = a.groupby(['uid', 'tanggal']).size().reset_index(name='count')

# Mengambil UID yang muncul minimal 2 kali setiap hari
filtered_uids = count_per_day[count_per_day['count'] >= 2]['uid']

# Menghitung total kemunculan setiap UID
total_counts = filtered_uids.value_counts()

# Mendapatkan UID dengan total kemunculan paling banyak
most_frequent_uid = total_counts.idxmax()

print(f"UID dengan kemunculan paling banyak adalah: {most_frequent_uid}")
total_counts = pd.DataFrame(total_counts)
total_counts.sort_values(by='count', ascending=False)
# Out:
# UID dengan kemunculan paling banyak adalah: f501c8a1-e251-4b8c-87fc-9a1a26d2e19d
#                                       count
# uid
# f501c8a1-e251-4b8c-87fc-9a1a26d2e19d      5
# a36ea4b5-8ee8-4f16-9d80-307e39a7aeba      4
# 4a2de4fb-2878-41ae-bc12-2890dc0f62b8      3
# 6065d08e-1b9a-45ed-9042-fc0773b25d3a      3
# 85ef87a8-f761-46bc-94dc-e0f08789efb4      2
# ...                                     ...
# ffc7892e-923c-49ef-8f3c-486107454e53      1
# ffcd6905-e12b-4fb6-bed9-f88380c6ffc8      1
# ffd7b1eb-b4f9-4a13-838f-078e53b94d10      1
# ffe248db-56ad-4d91-843c-00f36583940c      1
# fff98271-0aa0-49dd-9552-0566aac0e6c5      1
#
# [3307 rows x 1 columns]

# %%
c = df2.sort_values(by='uid')
c.head(10)
# Out:
#                                      uid       lat         lng  \
# 12  0021d9ff-90ea-4f94-88c9-8aa3408378ae -7.801390  110.364998
# 13  0021d9ff-90ea-4f94-88c9-8aa3408378ae -7.801390  110.364998
# 14  0021d9ff-90ea-4f94-88c9-8aa3408378ae -7.801390  110.364998
# 15  0021d9ff-90ea-4f94-88c9-8aa3408378ae -7.801390  110.364998
# 21  0036b971-96c4-4d06-94f2-570e0b941277 -7.793092  110.366120
# 22  004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.365000
# 23  004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.364998
# 24  00527875-c216-4ca7-9a67-a931fd28c779 -7.801390  110.364998
# 25  00527875-c216-4ca7-9a67-a931fd28c779 -7.801390  110.364998
# 32  0061fba2-4e1f-43ca-84ab-d26681ab6c97 -7.797887  110.365900
#
#               datetime                             geometry  \
# 12 2021-12-28 21:55:17  POINT (110.36499786376952 -7.80139)
# 13 2021-12-28 21:56:22  POINT (110.36499786376952 -7.80139)
# 14 2021-12-28 21:59:58  POINT (110.36499786376952 -7.80139)
# 15 2021-12-28 22:02:13  POINT (110.36499786376952 -7.80139)
# 21 2021-12-15 06:22:03          POINT (110.36612 -7.793092)
# 22 2021-12-26 18:42:55             POINT (110.365 -7.80139)
# 23 2021-12-26 18:43:35  POINT (110.36499786376952 -7.80139)
# 24 2021-12-24 05:57:52  POINT (110.36499786376952 -7.80139)
# 25 2021-12-24 06:05:20  POINT (110.36499786376952 -7.80139)
# 32 2021-12-01 05:29:01           POINT (110.3659 -7.797887)
#
#            Kelurahan/Desa   Kecamatan        Kabupaten     tanggal
# 12     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-28
# 13     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-28
# 14     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-28
# 15     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-28
# 21  Kelurahan Suryatmajan   Danurejan  Kota Yogyakarta  2021-12-15
# 22     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-26
# 23     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-26
# 24     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-24
# 25     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-24
# 32     Kelurahan Ngupasan  Gondomanan  Kota Yogyakarta  2021-12-01

# %%
stdf_df[stdf_df['maid'] == '0021d9ff-90ea-4f94-88c9-8aa3408378ae']
# Out:
# Empty DataFrame
# Columns: [uid, lat, lng, datetime, geometry, Kelurahan/Desa, Kecamatan, Kabupaten, tanggal, leaving_datetime]
# Index: []

# %% [markdown]
# # All above preprocessing in one cell

# %%
# before preprocessing
path = '../DataGPS_Affandi/filter2_affandi_mar.csv'
df = pd.read_csv(path)
df.info()
bar_chart(df)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1960 entries, 0 to 1959
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   maid            1960 non-null   object
#  1   latitude        1960 non-null   float64
#  2   longitude       1960 non-null   float64
#  3   datetime_wib    1960 non-null   object
#  4   geometry        1960 non-null   object
#  5   Kelurahan/Desa  1960 non-null   object
#  6   Kecamatan       1960 non-null   object
#  7   Kabupaten       1960 non-null   object
#  8   tanggal         1960 non-null   object
# dtypes: float64(2), object(7)
# memory usage: 137.9+ KB

# %%
# after preprocessing
df_after = third_preprocessing(df)
df_after.info()
bar_chart(df_after)
filename = path.replace('filter2', 'filter3')

# save filter result to csv
if os.path.exists(path):
    df_after.to_csv(filename, index=False)
else:
    print(f"The file path {path} does not exist.")
# Out:
# Number of points dropped from original data: 1551
# <class 'pandas.core.frame.DataFrame'>
# Index: 408 entries, 59 to 1902
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   maid            408 non-null    object
#  1   latitude        408 non-null    float64
#  2   longitude       408 non-null    float64
#  3   datetime_wib    408 non-null    datetime64[ns]
#  4   geometry        408 non-null    object
#  5   Kelurahan/Desa  408 non-null    object
#  6   Kecamatan       408 non-null    object
#  7   Kabupaten       408 non-null    object
#  8   tanggal         408 non-null    object
# dtypes: datetime64[ns](1), float64(2), object(6)
# memory usage: 31.9+ KB

# %%
a = df_after.sort_values(by=['maid', 'datetime_wib'])
a.head(20)
# Out:
#                                      maid  latitude   longitude  \
# 21   004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.365000
# 22   004c59b3-b2d0-4369-bd52-022203e04a51 -7.801390  110.364998
# 33   0077b22a-bc83-4dc5-a748-3b16fd4c7893 -7.800784  110.365456
# 34   0077b22a-bc83-4dc5-a748-3b16fd4c7893 -7.800784  110.365456
# 35   00886369-540d-4f73-b4d3-b8b8cdf5f7fb -7.801390  110.365000
# 36   00886369-540d-4f73-b4d3-b8b8cdf5f7fb -7.801390  110.365000
# 37   00ac9aac-851f-4b1a-b554-cc1f75d02fcd -7.799030  110.365288
# 38   00ac9aac-851f-4b1a-b554-cc1f75d02fcd -7.799030  110.365288
# 56   00cba227-d6b8-4518-ab6c-8c3ac3ded8b7 -7.796290  110.364578
# 57   00cba227-d6b8-4518-ab6c-8c3ac3ded8b7 -7.796290  110.364571
# 73   010799a0-ba92-4603-bf69-5c7158c7d082 -7.801390  110.364998
# 74   010799a0-ba92-4603-bf69-5c7158c7d082 -7.801390  110.365000
# 75   010e249e-cbca-4333-b4e5-d2c5e3d7e966 -7.801390  110.365000
# 76   010e249e-cbca-4333-b4e5-d2c5e3d7e966 -7.801390  110.365000
# 97   01503433-e1ce-4c70-9877-befc6bca949a -7.801390  110.364998
# 98   01503433-e1ce-4c70-9877-befc6bca949a -7.801390  110.364998
# 108  01a27430-79c9-4fbf-bbbb-f836eeefdecb -7.801390  110.365000
# 109  01a27430-79c9-4fbf-bbbb-f836eeefdecb -7.801390  110.364998
# 110  01a27430-79c9-4fbf-bbbb-f836eeefdecb -7.801390  110.365000
# 136  01ff62f2-8d4b-4304-bdce-24a01c119c59 -7.799190  110.366150
#
#            datetime_wib                              geometry  \
# 21  2021-12-26 18:42:55              POINT (110.365 -7.80139)
